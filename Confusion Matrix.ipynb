# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.utils.multiclass import unique_labels
import numpy as np
from packages.Utility.Metrics import ConfusionMatrix
from matplotlib.colors import LinearSegmentedColormap

# %%
y_true = np.array([0, 0, 0, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5, 6, 6, 6, 7, 7, 7, 8, 8, 8])
y_pred = np.array([0, 0, 0, 1, 1, 3, 2, 2, 3, 3, 2, 2, 4, 5, 4, 5, 5, 5, 6, 6, 6, 7, 7, 5, 8, 8, 8])
classes = np.array(["Nol", "Satu", "Dua", "Tiga","Empat","Lima","Enam","Tujuh","Delapan"])

# %%
cfm = ConfusionMatrix((30, 15), 1, 2, classes)
cfm.add(y_true, y_pred, 'Data Learning', cmap = plt.cm.YlGnBu)
cfm.add(y_true, y_pred, 'Data Testing', cmap = plt.cm.PuBuGn)
cfm.show()
