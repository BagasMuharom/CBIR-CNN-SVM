# %%
import numpy as np
from packages.Utility.CNN.Callbacks import *
from packages.Utility.DatasetManager import DatasetReader
from packages.Utility.Gabor import GaborFilterBanks, GaborParams
from packages.Model.CFNet import CFNet1
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Inisialisasi / Persiapan

# %%
fold_index = 0
dataset_dir = 'dataset/bin/CF.32.B.30K'
trained_dir = 'trained/CF.32.B.30K CF1.1'

# %% [markdown]
# # Memuat Dataset

# %%
reader = DatasetReader(dataset_dir)

X_train, Y_train_onehot, Y_train_single = reader.getTrainData(fold_index)
X_test, Y_test_onehot, Y_test_single = reader.getTestData(fold_index)

# %% [markdown]
# # Inisiasi Callbacks

# %%
val_model = ValidateModel(X_train, Y_train_onehot)
save_model = SaveModel(val_model, base_dir = trained_dir, fold = fold_index + 1, min_acc = 0.05)
stop_train = StopTraining(val_model)
history_save = HistorySaver(val_model, base_dir = trained_dir, fold = fold_index + 1)

# %% [markdown]
# # Parameter Gabor

# %%
class ChannelizeGaborParams(GaborParams):
    
    def getParams(self, shape, i, j):
        multiplier = 360 / shape[3]
        degree = multiplier * i
        
        i += 1
        j += 1
        
        lambd = (i * j) / shape[2]
        theta = degree * np.pi / 180
        psi = (i + j) / shape[2]
        sigma = (i + j)
        gamma = (i + j) / shape[2]
        
        return lambd, theta, psi, sigma, gamma

# %% [markdown]
# # Mendefinisikan Kernel Gabor

# %%
kernel1 = GaborFilterBanks(ChannelizeGaborParams())
kernel2 = GaborFilterBanks(ChannelizeGaborParams())
kernel3 = GaborFilterBanks(ChannelizeGaborParams())
kernel4 = GaborFilterBanks(ChannelizeGaborParams())
kernel5 = GaborFilterBanks(ChannelizeGaborParams())
kernel6 = GaborFilterBanks(ChannelizeGaborParams())

# %% [markdown]
# # Mendefinisikan Model

# %%
ars = CFNet1(kernels = {
    1: kernel1,
    2: kernel2,
    3: kernel3,
    4: kernel4,
    5: kernel5,
    6: kernel6
}, loss = 'categorical_crossentropy', optimizer = 'adadelta')

model = ars.model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# c1 (Conv2D)                  (None, 32, 32, 32)        896
# _________________________________________________________________
# c2 (Conv2D)                  (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# c3 (Conv2D)                  (None, 16, 16, 64)        18496
# _________________________________________________________________
# c4 (Conv2D)                  (None, 16, 16, 64)        36928
# _________________________________________________________________
# mp4 (MaxPooling2D)           (None, 8, 8, 64)          0
# _________________________________________________________________
# c5 (Conv2D)                  (None, 8, 8, 128)         73856
# _________________________________________________________________
# c6 (Conv2D)                  (None, 8, 8, 128)         147584
# _________________________________________________________________
# mp6 (MaxPooling2D)           (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# output (Dense)               (None, 10)                20490
# =================================================================
# Total params: 307,498
# Trainable params: 307,498
# Non-trainable params: 0
# _________________________________________________________________

# %%
ars.save(f'{trained_dir}/Fold {fold_index + 1}/init.h5')

# %% [markdown]
# # Pelatihan

# %%
ars.compile()
history = model.fit(X_train, Y_train_onehot, epochs = 50, verbose = 1, batch_size = 128, callbacks=[val_model, save_model, history_save, stop_train], initial_epoch = 0)
# Out:
# Epoch 1/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# New best accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 0/50
# Epoch 2/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 1/50
# Epoch 3/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 2/50
# Epoch 4/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 3/50
# Epoch 5/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 4/50
# Epoch 6/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 5/50
# Epoch 7/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 6/50
# Epoch 8/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 7/50
# Epoch 9/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 8/50
# Epoch 10/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 9/50
# Epoch 11/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 10/50
# Epoch 12/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 11/50
# Epoch 13/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 12/50
# Epoch 14/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 13/50
# Epoch 15/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 14/50
# Epoch 16/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 15/50
# Epoch 17/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 16/50
# Epoch 18/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 17/50
# Epoch 19/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 18/50
# Epoch 20/50
# 22500/22500 [==============================] - 80s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 19/50
# Epoch 21/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 20/50
# Epoch 22/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 21/50
# Epoch 23/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 22/50
# Epoch 24/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 23/50
# Epoch 25/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 24/50
# Epoch 26/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 25/50
# Epoch 27/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 26/50
# Epoch 28/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 27/50
# Epoch 29/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 28/50
# Epoch 30/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 29/50
# Epoch 31/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 30/50
# Epoch 32/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 31/50
# Epoch 33/50
# 22500/22500 [==============================] - 80s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 32/50
# Epoch 34/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 33/50
# Epoch 35/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 34/50
# Epoch 36/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 35/50
# Epoch 37/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 36/50
# Epoch 38/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 37/50
# Epoch 39/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 38/50
# Epoch 40/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 39/50
# Epoch 41/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 40/50
# Epoch 42/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 41/50
# Epoch 43/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 42/50
# Epoch 44/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 43/50
# Epoch 45/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 44/50
# Epoch 46/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 45/50
# Epoch 47/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 46/50
# Epoch 48/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 47/50
# Epoch 49/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 48/50
# Epoch 50/50
# 22500/22500 [==============================] - 81s 4ms/step - loss: 14.6782 - acc: 0.0893
# Accuracy : 0.08933333333333333
# Model saved to disk
# Passes : 49/50
# History saved
